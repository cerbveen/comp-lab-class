# %%
# this notebook is for Week2-Assignment-4)
# cell-1| import libraries
import numpy as np              # numpy| data processing
import matplotlib.pyplot as plt # matplotlib| plotting

# %%
# cell-2| load data
DATA = np.loadtxt('./Data/1hz3_T310.run.25000000.energy.xvg',skiprows=29)
# numpy.loadtxt(fname,skiprows=)

# %%
# cell-3| figure 1
plt.figure(1)                       #
plt.title('Potential vs. Time')     #
plt.plot(LOAD[:,0]*1000,LOAD[:,1])   #
plt.xlabel('Time (ns)')
plt.ylabel('Potential (kJ/mol)')
#plt.axis([0,5*10^7])
plt.show()

# %%
plt.plot(LOAD[:,0]*1000,LOAD[:,2])
plt.xlabel('Time (ns)')
plt.ylabel('Kinetic Energy (kJ/mol)')
# Out:
# Text(0, 0.5, 'Kinetic Energy (kJ/mol)')

# %%
plt.plot(LOAD[:,0]*1000,LOAD[:,3])
plt.xlabel('Time (ns)')
plt.ylabel('Totoal Energy (kJ/mol)')
# Out:
# Text(0, 0.5, 'Totoal Energy (kJ/mol)')

# %%
plt.plot(LOAD[:,0]*1000,LOAD[:,4])
plt.xlabel('Time (ns)')
plt.ylabel('Temperature (K)')
# Out:
# Text(0, 0.5, 'Temperature (K)')

# %%
plt.plot(LOAD[:,0]*1000,LOAD[:,5])
plt.xlabel('Time (ns)')
plt.ylabel('Pressure (bar)')
# Out:
# Text(0, 0.5, 'Pressure (bar)')

# %%
plt.plot(LOAD[:,0]*1000,LOAD[:,6])
plt.xlabel('Time (ns)')
plt.ylabel('Volume (nm^3)')
# Out:
# Text(0, 0.5, 'Volume (nm^3)')
