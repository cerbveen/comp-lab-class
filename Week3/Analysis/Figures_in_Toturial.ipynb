# %%
# # this notebook is for Week3-Assignment-plot figures in tutorial
# author: Rui Zeng, N15471955, rz2522@nyu.edu
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# figure 1 - Energy Minimization
# load data
DATA = np.loadtxt('../Data/potential.xvg',skiprows=24)
# plot
fig = plt.figure(1)                           # create figure 1
# title & labels
plt.text(x=0.5, y=0.88, s="Energy Minimization", fontsize=18, ha="center", transform=fig.transFigure)
plt.text(x=0.5, y=0.82, s= "1AKI, Steepest Descent", fontsize=11, ha="center", transform=fig.transFigure)
plt.subplots_adjust(top=0.8, wspace=0.3)
plt.xlabel('Energy Minimization Step (ps)',fontsize=14)    # x-axis label
plt.ylabel('Potential Energy (kJ/mol)',fontsize=14)        # y-axis label
# plot, change x to ps, colorblind friendly, linestyle, linewidth
plt.plot(DATA[:,0],DATA[:,1],color='#0072B2',label='Potential',linestyle='-',linewidth=1)
# change legend location
plt.legend(loc='upper right', fontsize=12)
# adjust axis range
plt.xlim(0,800)                          # x-axis range
plt.xticks(np.arange(0,801,200))
# change y-axis to scientific notation
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)
# save figure as pdf in ../Figures
fname = '../Figures/fig1.Energy Minimization.pdf'
plt.savefig(fname, format='pdf', dpi=300, bbox_inches='tight')

# %%
# figure 2 - NVT Equilibration
# load data
DATA = np.loadtxt('../Data/temperature.xvg',skiprows=24)
# plot
fig = plt.figure(2)                           # create figure 2
# title & labels
plt.text(x=0.5, y=0.88, s="Temperature", fontsize=18, ha="center", transform=fig.transFigure)
plt.text(x=0.5, y=0.82, s= "1AKI, NVT Equilibration", fontsize=11, ha="center", transform=fig.transFigure)
plt.subplots_adjust(top=0.8, wspace=0.3)
plt.xlabel('Time (ps)',fontsize=14)    # x-axis label
plt.ylabel('Temperature (K)',fontsize=14)        # y-axis label
# plot, change x to ps, colorblind friendly, linestyle, linewidth
plt.plot(DATA[:,0],DATA[:,1],color='#0072B2',linestyle='-',linewidth=1)
# change legend location
#plt.legend(loc='upper right', fontsize=12)
# adjust axis range
plt.xlim(0,100)                          # x-axis range
plt.xticks(np.arange(0,101,20))
plt.ylim(294,306)                          # y-axis range
# change y-axis to scientific notation
#plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0), useMathText=True)
# save figure as pdf in ../Figures
fname = '../Figures/fig2.NVT Equilibration.pdf'
plt.savefig(fname, format='pdf', dpi=300, bbox_inches='tight')

# %%
# figure 3 - NPT Equilibration-Pressure
# load data
from numpy import ones
DATA = np.loadtxt('../Data/pressure.xvg',skiprows=24)
# plot
fig = plt.figure(3)                           # create figure 3
# title & labels
plt.text(x=0.5, y=0.88, s="Pressure", fontsize=18, ha="center", transform=fig.transFigure)
plt.text(x=0.5, y=0.82, s= "1AKI, NPT Equilibration", fontsize=11, ha="center", transform=fig.transFigure)
plt.subplots_adjust(top=0.8, wspace=0.3)
plt.xlabel('Time (ps)',fontsize=14)    # x-axis label
plt.ylabel('Pressure (bar)',fontsize=14)        # y-axis label
# compute 10-ps running average
N = 10
running_avg = np.convolve(DATA[:,1], ones((N))/N, mode='valid')
# plot, change x to ps, colorblind friendly, linestyle, linewidth
plt.plot(DATA[:,0][N-1:],running_avg,color='#D55E00',linestyle='-',linewidth=1)
# plot, change x to ps, colorblind friendly, linestyle, linewidth
plt.plot(DATA[:,0],DATA[:,1],color='#0072B2',linestyle='-',linewidth=1)
# change legend location and color to match running average
plt.legend(['10-ps Running Avg'],loc='upper right', fontsize=12, facecolor='white')
# adjust axis range
plt.xlim(0,100)                          
plt.xticks(np.arange(0,101,20))
plt.ylim(-500,500)                          
plt.yticks(np.arange(-500,501,250))
# save figure as pdf in ../Figures
fname = '../Figures/fig3.NPT Equilibration-Pressure.pdf'
plt.savefig(fname, format='pdf', dpi=300, bbox_inches='tight')

# %%
# figure 4 - NPT Equilibration-density
# load data
DATA = np.loadtxt('../Data/density.xvg',skiprows=24)
# plot
fig = plt.figure(4)                           # create figure 4
# title & labels
plt.text(x=0.5, y=0.88, s="Density", fontsize=18, ha="center", transform=fig.transFigure)
plt.text(x=0.5, y=0.82, s= "1AKI, NPT Equilibration", fontsize=11, ha="center", transform=fig.transFigure)
plt.subplots_adjust(top=0.8, wspace=0.3)
plt.xlabel('Time (ps)',fontsize=14)    # x-axis label
plt.ylabel('Density (g/cm$^3$)',fontsize=14)        # y-axis label
# compute 10-ps running average
N = 10
running_avg = np.convolve(DATA[:,1], ones((N))/N, mode='valid')
# plot, change x to ps, colorblind friendly, linestyle, linewidth, match the x_range of running average
plt.plot(DATA[:,0][N-1:],running_avg,color='#D55E00',linestyle='-',linewidth=1)
# plot, change x to ps, colorblind friendly, linestyle, linewidth
plt.plot(DATA[:,0],DATA[:,1],color='#0072B2',linestyle='-',linewidth=1)
# change legend location and color to match running average
plt.legend(['10-ps Running Avg'],loc='upper right', fontsize=12, facecolor='white')
# adjust axis range
plt.xlim(0,100)
plt.xticks(np.arange(0,101,20))
plt.yticks(np.arange(990,1010,4))
# save figure as pdf in ../Figures
fname = '../Figures/fig4.NPT Equilibration-Density.pdf'
plt.savefig(fname, format='pdf', dpi=300, bbox_inches='tight')

# %%
# figure 5 - Analysis-RMSD  
# load data
DATA1 = np.loadtxt('../Data/rmsd.xvg',skiprows=18)
DATA2 = np.loadtxt('../Data/rmsd_xtal.xvg',skiprows=18)
# plot
fig = plt.figure(5)                           # create figure 5
# title & labels
plt.text(x=0.5, y=0.88, s="RMSD", fontsize=18, ha="center", transform=fig.transFigure)
plt.text(x=0.5, y=0.82, s= "1AKI, Backbone", fontsize=11, ha="center", transform=fig.transFigure)
plt.subplots_adjust(top=0.8, wspace=0.3)
plt.xlabel('Time (ns)',fontsize=14)    # x-axis label
plt.ylabel('RMSD (nm)',fontsize=14)        # y-axis label
# plot, change x to ps, colorblind friendly, linestyle, linewidth
plt.plot(DATA1[:,0],DATA1[:,1],color='#0072B2',linestyle='-',linewidth=1)
# plot, change x to ps, colorblind friendly, linestyle, linewidth
plt.plot(DATA2[:,0],DATA2[:,1],color='#D55E00',linestyle='-',linewidth=1)
# change legend location
plt.legend(['Ref:Equilibrated','Ref:Crystal'],loc='lower right', fontsize=12, facecolor='white')
# adjust axis range
plt.xlim(0,1)
plt.xticks(np.arange(0,1.1,0.2))
# save figure as pdf in ../Figures
fname = '../Figures/fig5.Analysis-RMSD.pdf'
plt.savefig(fname, format='pdf', dpi=300, bbox_inches='tight')

# %%
# figure 6 - Analysis-Radius of gyration
# load data
DATA = np.loadtxt('../Data/gyrate.xvg',skiprows=27)
# plot
fig = plt.figure(6)                           # create figure 6
# title & labels
plt.text(x=0.5, y=0.88, s="Radius of gyration", fontsize=18, ha="center", transform=fig.transFigure)
plt.text(x=0.5, y=0.82, s= "1AKI, Unrestrained MD", fontsize=11, ha="center", transform=fig.transFigure)
plt.subplots_adjust(top=0.8, wspace=0.3)
plt.xlabel('Time (ns)',fontsize=14)    # x-axis label
plt.ylabel(r'R$_g$ (nm)',fontsize=14)        # y-axis label
# plot, change x to ps, colorblind friendly, linestyle, linewidth
plt.plot(DATA[:,0]/1000,DATA[:,1],color='#0072B2',linestyle='-',linewidth=1)
# adjust axis range
plt.xlim(0,1)
plt.xticks(np.arange(0,1.1,0.2))
plt.yticks(np.arange(1.3,1.51,0.05))
# save figure as pdf in ../Figures
fname = '../Figures/fig6.Analysis-RG.pdf'
plt.savefig(fname, format='pdf', dpi=300, bbox_inches='tight')
